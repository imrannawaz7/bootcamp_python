# %%
#Create three variables in a single a line and assign different values to them and make sure their data types are different. Like one is int, another one is float and the last one is a string.

a = 12
b = 0.09
c = 'Hello'
print(a,b,c)
# Out:
# 12 0.09 Hello

# %%
#Create a variable of value type complex and swap it with another variable whose value is an integer.
a=12
y=5
x=complex(a)
x,y=y,x
print(x,y)
# Out:
# 5 (12+0j)

# %%
#Swap two numbers using the third variable as the result name and do the same task without using any third variable.
x=45
y=25
x,y,a=y,x,a
a=x+y
result=a
print(result)
print(x,y)
# Out:
# 70
# 25 45

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %%
# If one data type value is assigned to ‘a’ variable and then a different data type value is assigned to ‘a’ again. Will it change the value. If Yes then Why?
Yes, it will change. Because Python considers the later value assigned to the variable.
Example:
    x = 2 -->int
    y = 0.2 -->float
    x = y 
The final value will be float since y's value was assigned to x.

# %%
#Write a program to complete the task given below:
#Ask the user to enter any 2 numbers in between 1-10 and add both of them to another variable call z.
#Use z for adding 30 into it and print the final result by using variable resul

X = input("Enter value 1 between 1 to 10: ")
Y = input("Enter value 1 between 1 to 10: ")
Z = int(X) + int(Y)
print(Z)
# Out:
# Enter value 1 between 1 to 10: 3
# Enter value 1 between 1 to 10: 3
# 6

# %%
X = input("Enter value 1 between 1 to 10: ")
Y = input("Enter value 1 between 1 to 10: ")
Z = int(X) + int(Y)
C = 30
print(Z + C)
# Out:
# Enter value 1 between 1 to 10: 3
# Enter value 1 between 1 to 10: 5
# 38

# %%
#Write a program to check the data type of the entered values. HINT: Printed output should say -  The input value data type is: int/float/string/etc
a = 10
b = 0.10
c = '10'
d = [10,13,11]
print("The input value data type is: ",type(a),"/",type(b),"/",type(c),"/",type(d))
# Out:
# The input value data type is:  <class 'int'> / <class 'float'> / <class 'str'> / <class 'list'>

# %%
#If one data type value is assigned to ‘a’ variable and then a different data type value is assigned to ‘a’ again. Will it change the value. If Yes then Why?

# %%
# Write a program in Python to perform the following operation:
# If a number is divisible by 3 it should print “Consultadd” as a string
# If a number is divisible by 5 it should print “c” as a string
# If a number is divisible by both 3 and 5 it should print “Consultadd Python Training” as a string.
x = int(input("Enter a number: "))
if(x%3==0 and x%5!=0):
    print("Consultadd")
elif (x%5==0 and x%3!=0):
    print('c')
elif (x%3==0 and x%5==0):
    print("Consultadd Python Training")
# Out:
# Enter a number: 5
# c

# %%
# Write a program in Python to perform the following operator based task:
# Ask user to choose the following option first:
# If User Enter 1 - Addition 
# If User Enter 2 - Subtraction
# If User Enter 3 - Division
# If USer Enter 4 - Multiplication
# If User Enter 5 - Average
operator = int(input('1 - Addition, 2_Subraction, 3 - Division, 4 - Multiplication, 5 - Average | Which operator would you like to use? '))

if operator==1:
    a = int(input("Number 1: "))
    b = int(input("Number 2: "))
    Result =(a + b)
    print(Result)
    if Result < 0:
        print('zsa')
elif operator==2:
    a = int(input("Number 1: "))
    b = int(input("Number 2: "))
    Result =(a - b)
    print(Result)
    if Result < 0:
        print('zsa')
elif operator==3:
    a = int(input("Number 1: "))
    b = int(input("Number 2: "))
    Result =(a / b)
    print(Result)
    if Result < 0:
        print('zsa')
elif operator==4:
    a = int(input("Number 1: "))
    b = int(input("Number 2: "))
    Result =(a * b)
    print(Result)
    if Result < 0:
        print('zsa')
elif operator==5:
    est = []
    n = int(input('Enter number of elements'))
    for i in range(0,n):
        ele = int(input())
        
        est.append(ele)
    print('Average ',sum(est)/len(est))
    if Result < 0:
        print('zsa')

# %% [markdown]
# a = 10
# b = 20
# c = 30
# avg = (a + b +c)/3

# %%
a = int(input("Enter the value a: "))
b = int(input("Enter the value b: "))
c = int(input("Enter the value c: "))

avg = (a + b + c) / 3

if avg > a and avg > b and avg > c:
    print("The avg is greater than a, b, c ")
elif avg > a and avg > b:
    print("The avg is greater than a and b ")
elif avg > a and avg > c:
    print("The avg is greater than a and c ")
elif avg > b and avg > c:
    print("The avg is greater than b and c: ")
elif avg > a:
    print("The avg is greater than a ")
elif avg > b:
    print("The avg is greater than b ")
elif avg > c:
    print("The avg is greater than c ")
print("average: ", avg)

# %%
# Write a program in Python to break and continue if the following cases occurs:
# If user enters a negative number just break the loop and print “It’s Over”
# If user enters a positive number just continue in the loop and print “Good Going”
x = 1
while x > 0:
    x = int(input("Enter a value: "))
    if x < 0:
        break
    elif x > 0:
        print("Good going")
print('Its over')

# %%
# Write a program in Python which will find all such numbers which are divisible  by 7 but are not a multiple of 5, between 2000 and 3200.

x = 2000

while x < 3201:
    if x % 7 == 0 and x % 5 !=0:
        print(x)
    x += 1
# Out:
# 2002
# 2009
# 2016
# 2023
# 2037
# 2044
# 2051
# 2058
# 2072
# 2079
# 2086
# 2093
# 2107
# 2114
# 2121
# 2128
# 2142
# 2149
# 2156
# 2163
# 2177
# 2184
# 2191
# 2198
# 2212
# 2219
# 2226
# 2233
# 2247
# 2254
# 2261
# 2268
# 2282
# 2289
# 2296
# 2303
# 2317
# 2324
# 2331
# 2338
# 2352
# 2359
# 2366
# 2373
# 2387
# 2394
# 2401
# 2408
# 2422
# 2429
# 2436
# 2443
# 2457
# 2464
# 2471
# 2478
# 2492
# 2499
# 2506
# 2513
# 2527
# 2534
# 2541
# 2548
# 2562
# 2569
# 2576
# 2583
# 2597
# 2604
# 2611
# 2618
# 2632
# 2639
# 2646
# 2653
# 2667
# 2674
# 2681
# 2688
# 2702
# 2709
# 2716
# 2723
# 2737
# 2744
# 2751
# 2758
# 2772
# 2779
# 2786
# 2793
# 2807
# 2814
# 2821
# 2828
# 2842
# 2849
# 2856
# 2863
# 2877
# 2884
# 2891
# 2898
# 2912
# 2919
# 2926
# 2933
# 2947
# 2954
# 2961
# 2968
# 2982
# 2989
# 2996
# 3003
# 3017
# 3024
# 3031
# 3038
# 3052
# 3059
# 3066
# 3073
# 3087
# 3094
# 3101
# 3108
# 3122
# 3129
# 3136
# 3143
# 3157
# 3164
# 3171
# 3178
# 3192
# 3199

# %%
# What is the output of the following code examples?

# %%
x=123 

for i in x:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3ab420552a42> in <module>
#       1 x=123
#       2
# ----> 3 for i in x:
#       4     print(i)
#
# TypeError: 'int' object is not iterable

# %%
i = 0
while i < 5:
    print(i)
    i += 1
    if i == 3:
        break
    else:
        print('error')
# Out:
# 0
# error
# 1
# error
# 2

# %%
count = 0
while True:
    print(count)
    count += 1
    if count >= 5:
        break
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Write a program that prints all the numbers from 0 to 6 except 3 and 6.
#        Expected output: 0 1 2 4 5
# Note: Use ‘continue’ statement
for a in range(0,7):
    if a ==3 or a == 6:
        continue
    print(a)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
# Write a program that accepts a string as an input from user and calculate the number of digits and letters.
#      Expected output: consul12
#      Letters 6
#      Digits 2
a = input("Enter the string with numbers: ")
print("Given string:",a)
x = 0
y = 0
for i in a:
    if i.isdigit():
        x+=1
    else:
        y += 1
        continue
print("Letters:" , x, "Digits: ", y)

# %%
#  Write a program such that it asks users to “guess the lucky number”. If the correct number is guessed the program stops, otherwise it continues forever. 
b = 60 
a = int(input("Guess the lucky number: ")) 
while (a!=b): 
    if a < 0 or b > 59: 
        print("Sorry, Guess Again!") 
    a = int(input()) 
    continue 
print("Good guess! ")

# %%
# Modify the program so that it asks users whether they want to guess again each time. Use two variables, ‘number’ for the number and ‘answer’ for the answer to the question whether they want to continue guessing. The program stops if the user guesses the correct number or answers “no”. ( The program continues as long as a user has not answered “no” and has not guessed the correct number)
b = 20
a = int(input("Guess the lucky number: ")) 
while (a!=b): 
    if a < 0 or b > 20: 
        print("Sorry, Guess Again!")
        s = int(input('do you wanna guess again?: 1 for yes, 2 for no'))
        if s == 1:
            a = int(input("Guess:'))
        elif s == 2:
            print('20')
# Out:
# Guess the lucky number: 5
# Sorry, Guess Again!
# do you wanna guess again?: 1 for yes, 2 for no1
# Guess:2
# Sorry, Guess Again!
# do you wanna guess again?: 1 for yes, 2 for no1
# Guess:60

# %%
# Write a program that asks five times to guess the lucky number. Use a while loop and a counter, such as
#            		counter=1
# 		While counter <= 5:
# 			print(“Type in the”, counter, “number”
# 			counter=counter+1
# The program asks for five guesses (no matter whether the correct number was guessed or not). If the correct number is guessed, the program outputs “Good guess!”, otherwise it outputs “Try again!”. After the fifth guess it stops and prints “Game over!”.

a=10
count=1
while(count<=5):
    b=int(input("Guess the lucky number"))
    if(b==a):
        print("Good guess")
        print("Entered number is correct",a)
        break
    else:
        print("Try again!")
        count+=1
        
print("Game Over")
# Out:
# Guess the lucky number3
# Try again!
# Guess the lucky number2
# Try again!
# Guess the lucky number10
# Good guess
# Entered number is correct 10

# %%
# . In the previous question, insert “break” after the “Good guess!” print statement. “break” will terminate the while loop so that users do not have to continue guessing after they found the number. If the user does not guess the number at all, print “Sorry but that was not very successful”.
a=10
count=1
while(count<=5):
    b=int(input("Guess the lucky number"))
    if(b==a):
        print("Good guess")
        break
        print("Entered number is correct",a)
        break
    else:
        print("Try again!")
        count+=1
while count == 5:
    print('Game over! Please restart!')
